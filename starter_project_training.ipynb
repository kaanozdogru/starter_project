# %% [markdown]
# ## installs

# %%
# !pip install yt-dlp
# !apt-get install ffmpeg
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 32.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 27.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 84.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 19.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 108.6 MB/s eta 0:00:00
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 18 not upgraded.

# %%
import os

# %% [markdown]
# ## rest

# %%
sports_videos = {
    'ballet': [
        'https://www.youtube.com/watch?v=wr13tU8Nqsc',
        'https://www.youtube.com/watch?v=1YPj44YhkOA',
        'https://www.youtube.com/watch?v=AiTDqwY8cIA',
        'https://www.youtube.com/watch?v=x4xrr0F0C_I',
        'https://www.youtube.com/watch?v=BZJ7PeF2KP0',
        'https://www.youtube.com/watch?v=VlACrUEU_HQ',
        'https://www.youtube.com/watch?v=-wc8GLKGSQY',
        'https://www.youtube.com/watch?v=L5sbyJzeZkk',
        'https://www.youtube.com/watch?v=Ij5s-AE_AKc',
        'https://www.youtube.com/watch?v=yRw4oL1uIa4&t=259s'
    ],
    'archery': [
        'https://www.youtube.com/watch?v=pIJKDBvsaR0',
        'https://www.youtube.com/watch?v=6HTg42FbOr4',
        'https://www.youtube.com/watch?v=calRUAOcKgo',
        'https://www.youtube.com/watch?v=7HGIASAOoa0',
        'https://www.youtube.com/watch?v=8JIkLkQxW60',
        'https://www.youtube.com/watch?v=CrZh4HHIyNw',
        'https://www.youtube.com/watch?v=K63YSnHzT0U',
        'https://www.youtube.com/watch?v=tt_nonhryms',
        'https://www.youtube.com/watch?v=FjyZlGcjTsU'
    ],
    'basketball': [
        'https://www.youtube.com/watch?v=PBRJLqS1HVU',
        'https://www.youtube.com/watch?v=QRLKbY3NwIc',
        'https://www.youtube.com/watch?v=T7kTJPnnoR4',
        'https://www.youtube.com/watch?v=tAZFpExbX3Q',
        'https://www.youtube.com/watch?v=YMcgGPeBDZM',
        'https://www.youtube.com/watch?v=qj-yTYrKvCM',
        'https://www.youtube.com/watch?v=ZDtwhDQKo9Y',
        'https://www.youtube.com/watch?v=tIqGVumWpgA',
        'https://www.youtube.com/watch?v=PsTShMGjwYo'
    ],
    'rock_climbing': [
        'https://www.youtube.com/watch?v=1X5Vy19HvWw',
        'https://www.youtube.com/watch?v=zxW-b2pFu5U',
        'https://www.youtube.com/watch?v=RMH6WnkhRu8',
        'https://www.youtube.com/watch?v=MFmQpX_z3Lk',
        'https://www.youtube.com/watch?v=goY24JoHwIU',
        'https://www.youtube.com/watch?v=4PdVhf6EqNc',
        'https://www.youtube.com/watch?v=4CfyuiqFwRU',
        'https://www.youtube.com/watch?v=mzqN_tkBOSw',
        'https://www.youtube.com/watch?v=b2v4brHpdxY',
        'https://www.youtube.com/watch?v=nyszFWb5dn8'
    ],
    'tennis': [
        'https://www.youtube.com/watch?v=N3p7mLYcN9Y',
        'https://www.youtube.com/watch?v=lk3sef5gvrA',
        'https://www.youtube.com/watch?v=4n4uiW77C40',
        'https://www.youtube.com/watch?v=3fFChqk-0-M',
        'https://www.youtube.com/watch?v=MXv5iAUDYoA',
        'https://www.youtube.com/watch?v=zMfN8T6Giio',
        'https://www.youtube.com/watch?v=ZsuPHCfNS6o',
        'https://www.youtube.com/watch?v=p-ikn-WovLc'
    ],
    'golf': [
        'https://www.youtube.com/watch?v=tMTGNgZbXYU',
        'https://www.youtube.com/watch?v=DtDZiqpd_FA',
        'https://www.youtube.com/watch?v=XLU5-53gMwE',
        'https://www.youtube.com/watch?v=r5u52YuNVG8',
        'https://www.youtube.com/watch?v=BBbSwvV3bJI',
        'https://www.youtube.com/watch?v=KFSlEFnt5tU',
        'https://www.youtube.com/watch?v=F0JMkkSpnOI',
        'https://www.youtube.com/watch?v=71wHdktdCXA'
    ],
    'jj': [
      'https://www.youtube.com/watch?v=AReJUFsuczg',
      'https://www.youtube.com/watch?v=SsyCNg4m3Mc',
      'https://www.youtube.com/watch?v=jIabXnBi2gg',
      'https://www.youtube.com/watch?v=UEYnvzl9_6Q',
      'https://www.youtube.com/watch?v=fX4Q3Ha0j_s',
      'https://www.youtube.com/watch?v=bqdnbCcx0QE',
      'https://www.youtube.com/watch?v=235-CSlvAmw',
      'https://www.youtube.com/watch?v=r4yQpB5SDWE'
  ],
    'skateboarding': [
        'https://www.youtube.com/watch?v=VxoYD0FpAkM',
        'https://www.youtube.com/watch?v=dEEUWdh-6ek',
        'https://www.youtube.com/watch?v=SWDZ7qlINC0',
        'https://www.youtube.com/watch?v=yIqCp4XBzRo',
        'https://www.youtube.com/watch?v=GrOCMjotAuw',
        'https://www.youtube.com/watch?v=8IBAfd3VuNw',
        'https://www.youtube.com/watch?v=KTW5xEoFTsQ',
        'https://www.youtube.com/watch?v=nwaWcXek4b8',
        'https://www.youtube.com/watch?v=gdV3H11J9TI',
        'https://www.youtube.com/watch?v=gb6AwBP8hsI'
    ],
    'figure_skating': [
        'https://www.youtube.com/watch?v=iYXq544DjI4',
        'https://www.youtube.com/watch?v=hM2dFHSVIzM',
        'https://www.youtube.com/watch?v=L5tFYHHDkTc',
        'https://www.youtube.com/watch?v=ueYg76Srdrg',
        'https://www.youtube.com/watch?v=Ke5_FUoRli0',
        'https://www.youtube.com/watch?v=f2WTVFHtlc4',
        'https://www.youtube.com/watch?v=9IM3iFL9sY0',
        'https://www.youtube.com/watch?v=M-COxNujKr0',
        'https://www.youtube.com/watch?v=Z2PrQMOjF5I'
    ]
,
    'surfing': [
        'https://www.youtube.com/watch?v=e_UiYfLI7Sc',
        'https://www.youtube.com/watch?v=Bb1C0rqTqto',
        'https://www.youtube.com/watch?v=KMRJh29r3EA',
        'https://www.youtube.com/watch?v=_R7XbTsKbfs',
        'https://www.youtube.com/watch?v=hfX4AqRhh_k',
        'https://www.youtube.com/watch?v=l08BvcCC3sI',
        'https://www.youtube.com/watch?v=ncGzbStsPRQ',
        'https://www.youtube.com/watch?v=QfjizIxn1pc'
    ]
}

# %%
# /content/drive/MyDrive/starter_project/basketball/video/exercisevideo_2.webm
# !ffmpeg -i /content/drive/MyDrive/starter_project/basketball/video/exercisevideo_2.webm -vf scale=256:256 /content/drive/MyDrive/starter_project/basketball/video/exercisevideo_2.webm
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
for exercise_name in sports_videos.keys():
  print(exercise_name)
  for video_number, youtube_url in enumerate(sports_videos[exercise_name]):
    video_path = '/content/drive/MyDrive/starter_project/'+exercise_name+'/video/exercisevideo_'+str(video_number)+'.webm'

    # Construct the download command using video_path
    download_command = f'yt-dlp -o "{video_path}" {youtube_url}'


    # Execute the download command
    os.system(download_command)
# Out:
# ballet

# %%
for exercise_name in sports_videos.keys():
  print(exercise_name)
  for video_number, youtube_url in enumerate(sports_videos[exercise_name]):
    video_path = '/content/drive/MyDrive/starter_project/'+exercise_name+'/video/exercisevideo_'+str(video_number)+'.webm'

    # Construct the download command using video_path
    download_command = f'yt-dlp -o "{video_path}" {youtube_url}'


    # Execute the download command
    os.system(download_command)
# Out:
# tennis
# golf
# jj
# skateboarding
# figure_skating

# %%
exercises = ['archery', 'ballet', 'basketball','rock_climbing','skateboarding','golf', 'jj', 'figure_skating', 'surfing', 'tennis']
for exercise_name in exercises:
  print(exercise_name)
  os.mkdir(f'/content/{exercise_name}')
  exercise_path = f'/content/drive/MyDrive/starter_project/{exercise_name}/video/'
  output_path = f'/content/{exercise_name}/'


  video_list = os.listdir(exercise_path)

  for video in video_list:
    read_video_path = os.path.join(exercise_path, video)
    print(read_video_path)
    # write_video_path = os.path.join(exercise_path, video.split('.')[0]+'_%03d.mp4')
    write_video_path = os.path.join(output_path, video.split('.')[0]+'_%03d.mp4')
    split_command = f'ffmpeg -i {read_video_path} -c:v copy -an -segment_time 3 -f segment {write_video_path}'
    os.system(split_command)
    # os.system(f'rm {read_video_path}')
# Out:
# archery
# /content/drive/MyDrive/starter_project/archery/video/exercisevideo_0.webm
# /content/drive/MyDrive/starter_project/archery/video/exercisevideo_1.webm
# /content/drive/MyDrive/starter_project/archery/video/exercisevideo_2.webm
# /content/drive/MyDrive/starter_project/archery/video/exercisevideo_3.webm
# /content/drive/MyDrive/starter_project/archery/video/exercisevideo_8.webm
# /content/drive/MyDrive/starter_project/archery/video/.ipynb_checkpoints
# ballet
# /content/drive/MyDrive/starter_project/ballet/video/exercisevideo_1.webm
# /content/drive/MyDrive/starter_project/ballet/video/exercisevideo_2.webm
# /content/drive/MyDrive/starter_project/ballet/video/exercisevideo_3.webm
# /content/drive/MyDrive/starter_project/ballet/video/exercisevideo_4.webm
# /content/drive/MyDrive/starter_project/ballet/video/exercisevideo_6.webm
# /content/drive/MyDrive/starter_project/ballet/video/exercisevideo_7.webm
# /content/drive/MyDrive/starter_project/ballet/video/exercisevideo_8.webm
# ...

# %%
exercises = ['archery', 'ballet', 'basketball','rock_climbing','skateboarding','golf', 'jj', 'figure_skating', 'surfing', 'tennis']

concatted_list = []
sum=0
for exercise_name in exercises:
  video_path = f'/content/{exercise_name}'
  video_list = os.listdir(video_path)
  concatted_list+=[os.path.join(video_path, video) for video in video_list]
  # concatted_list+=os.listdir(video_path)


# concatted_list

# %%
sum
# Out:
# 0

# %%
len(concatted_list)
# Out:
# 8647

# %%
import random

# %%
# Shuffle the elements
random.shuffle(concatted_list)

# %%
with open("video_dataset.txt", "w") as f:
    for string in concatted_list:
        f.write(f"{string}\n")

# %%
class_labels = sorted({str(path).split("/")[2] for path in concatted_list})
class_labels
# Out:
# ['archery',
#  'ballet',
#  'basketball',
#  'figure_skating',
#  'golf',
#  'jj',
#  'rock_climbing',
#  'skateboarding',
#  'surfing',
#  'tennis']

# %%
class_labels = sorted({str(path).split("/")[2] for path in concatted_list})
label2id = {label: i for i, label in enumerate(class_labels)}
id2label = {i: label for label, i in label2id.items()}

print(f"Unique classes: {list(label2id.keys())}.")
# Out:
# Unique classes: ['archery', 'ballet', 'basketball', 'figure_skating', 'golf', 'jj', 'rock_climbing', 'skateboarding', 'surfing', 'tennis'].

# %%
label2id
# Out:
# {'archery': 0,
#  'ballet': 1,
#  'basketball': 2,
#  'figure_skating': 3,
#  'golf': 4,
#  'jj': 5,
#  'rock_climbing': 6,
#  'skateboarding': 7,
#  'surfing': 8,
#  'tennis': 9}

# %%
labels = [label2id[str(path).split("/")[2]] for path in concatted_list]

# %%
labels[0]
# Out:
# 5

# %%
concatted_list[0]
# Out:
# '/content/jj/exercisevideo_5_081.mp4'

# %%
dataset = [(path, label) for path,label in zip(concatted_list,labels)]
dataset[45]
# Out:
# ('/content/golf/exercisevideo_6_184.mp4', 4)

# %%
from sklearn.model_selection import train_test_split

train_data, test_data = train_test_split(dataset, test_size=0.2)

print("Training data:", train_data)
print("Test data:", test_data)
# Out:
# Training data: [('/content/archery/exercisevideo_8_051.mp4', 0), ('/content/golf/exercisevideo_2_212.mp4', 4), ('/content/rock_climbing/exercisevideo_9_161.mp4', 6), ('/content/skateboarding/exercisevideo_1_076.mp4', 7), ('/content/ballet/exercisevideo_1_048.mp4', 1), ('/content/ballet/exercisevideo_6_095.mp4', 1), ('/content/figure_skating/exercisevideo_5_037.mp4', 3), ('/content/tennis/exercisevideo_4_007.mp4', 9), ('/content/ballet/exercisevideo_4_097.mp4', 1), ('/content/tennis/exercisevideo_6_011.mp4', 9), ('/content/ballet/exercisevideo_3_038.mp4', 1), ('/content/golf/exercisevideo_6_126.mp4', 4), ('/content/skateboarding/exercisevideo_8_102.mp4', 7), ('/content/surfing/exercisevideo_0_159.mp4', 8), ('/content/figure_skating/exercisevideo_4_076.mp4', 3), ('/content/skateboarding/exercisevideo_6_042.mp4', 7), ('/content/golf/exercisevideo_2_175.mp4', 4), ('/content/basketball/exercisevideo_4_031.mp4', 2), ('/content/rock_climbing/exercisevideo_8_051.mp4', 6), ('/content/ballet/e
# ...

# %%
pip install pytorchvideo
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.7/132.7 kB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 7.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.0/31.0 MB 59.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 6.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pytorchvideo: filename=pytorchvideo-0.1.5-py3-none-any.whl size=188685 sha256=b680eb81d796c179f0da70caa05f39956d982a18f33eb5874a95a67ce5fb64b4
#   Stored in directory: /root/.cache/pip/wheels/ff/4e/81/0f72a543be9ed7eb737c95bfc5da4025e73226b44368074ece
# ...
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61400 sha256=1c50acdbfa1821940426dd668271b93d556aaeee7339ff72719826093a58702c
# ...

# %%
import torch
import json
from torchvision.transforms import Compose, Lambda
from torchvision.transforms._transforms_video import (
    CenterCropVideo,
    NormalizeVideo,
)
from pytorchvideo.data.encoded_video import EncodedVideo
from pytorchvideo.transforms import (
    ApplyTransformToKey,
    ShortSideScale,
    UniformTemporalSubsample,
    UniformCropVideo
)
from typing import Dict
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/_functional_video.py:6: UserWarning: The 'torchvision.transforms._functional_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms.functional' module instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/_transforms_video.py:22: UserWarning: The 'torchvision.transforms._transforms_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms' module instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(

# %%
device
# Out:
# device(type='cuda')

# %%
class ClassificationDataset(torch.utils.data.Dataset):
    def __init__(self, dataset) -> None:
        super().__init__()

        self.dataset = dataset

        side_size = 200
        mean = [0.45, 0.45, 0.45]
        std = [0.225, 0.225, 0.225]
        crop_size = 200
        num_frames = 8
        sampling_rate = 8
        frames_per_second = 30

        self.transform =  ApplyTransformToKey(
            key="video",
            transform=Compose(
                [
                    UniformTemporalSubsample(num_frames),
                    Lambda(lambda x: x/255.0),
                    NormalizeVideo(mean, std),
                    ShortSideScale(
                        size=side_size
                    ),
                    CenterCropVideo(crop_size=(crop_size, crop_size))
                ]
            ),
        )

    def __len__(self):
      return len(self.dataset)

    def __getitem__(self, idx):
      video_path, label = self.dataset[idx]
      video = EncodedVideo.from_path(video_path)
      video_data = video.get_clip(start_sec=0, end_sec=3)
      video_data = self.transform(video_data)
      inputs = video_data["video"]
      return inputs, label

# %%
train_data, test_data
classification_dataset_train = ClassificationDataset(dataset=train_data)
classification_dataset_test = ClassificationDataset(dataset=test_data)

batch_size = 4
classification_dataloader_train = torch.utils.data.DataLoader(classification_dataset_train, batch_size=batch_size, shuffle=True, num_workers=0)
classification_dataloader_test = torch.utils.data.DataLoader(classification_dataset_test, batch_size=batch_size, shuffle=True, num_workers=0)

dataloaders = {
    "train": classification_dataloader_train,
    "test": classification_dataloader_test
}

dataset_sizes = {
    "train": len(classification_dataset_train),
    "test": len(classification_dataset_test)
}

# %%
# Create an iterator from the DataLoader
data_iter = iter(classification_dataloader_train)

# Fetch the next batch
inputs, labels = next(data_iter)

# %%
inputs = inputs.to(device)
labels = labels.to(device)

# %%
import gc
gc.collect()
# Out:
# 0

# %%
import torch
import torch.nn as nn

model = torch.hub.load('facebookresearch/pytorchvideo', 'slow_r50', pretrained=True).to(device)
model.blocks[5].proj = nn.Linear(2048, 10).to(device)
# Out:
# Downloading: "https://github.com/facebookresearch/pytorchvideo/zipball/main" to /root/.cache/torch/hub/main.zip
# Downloading: "https://dl.fbaipublicfiles.com/pytorchvideo/model_zoo/kinetics/SLOW_8x8_R50.pyth" to /root/.cache/torch/hub/checkpoints/SLOW_8x8_R50.pyth
# 100%|██████████| 248M/248M [00:01<00:00, 246MB/s]

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.1)

# %%
device
# Out:
# device(type='cuda')

# %%
from tqdm import tqdm
import gc

num_epochs = 1
for epoch in range(num_epochs):
    for phase in ['train', 'val']:
        if phase == 'train':
            model.train()
        else:
            model.eval()

        running_loss, running_corrects = 0.0, 0
        counter = 0
        for inputs, labels in tqdm(dataloaders[phase], desc= f"epoch {str(epoch).zfill(3)} | phase {phase.ljust(5)}"):
            inputs = inputs.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()

            with torch.set_grad_enabled(phase == 'train'):
                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)
                loss = criterion(outputs, labels)

                if phase == 'train':
                    loss.backward()
                    optimizer.step()

            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)
            print(loss.item())
            print(torch.sum(preds == labels.data)/batch_size)
            # Clear memory and collect garbage
            del inputs, labels, outputs, preds
            gc.collect()
            counter += 1
            if counter % 100 == 0:
              torch.save(model, '/content/drive/MyDrive/starter_project/model_complete.pth')
              print(f'{phase} Loss: {running_loss:.4f}')
              running_loss = 0.0
              running_corrects = 0




        if phase == 'train':
            scheduler.step()

        epoch_loss = running_loss / dataset_sizes[phase]
        epoch_acc = running_corrects.double() / dataset_sizes[phase]
# Out:
# epoch 000 | phase train:   0%|          | 1/1730 [00:17<8:27:25, 17.61s/it]
# 2.4851136207580566
# tensor(0., device='cuda:0')
# epoch 000 | phase train:   0%|          | 2/1730 [00:27<6:13:29, 12.97s/it]
# 2.0999302864074707
# tensor(0., device='cuda:0')
# epoch 000 | phase train:   0%|          | 3/1730 [00:37<5:30:41, 11.49s/it]
# 2.2035346031188965
# tensor(0.2500, device='cuda:0')
# epoch 000 | phase train:   0%|          | 4/1730 [00:57<7:06:52, 14.84s/it]
# 2.583760976791382
# tensor(0.2500, device='cuda:0')
# epoch 000 | phase train:   0%|          | 5/1730 [01:20<8:35:28, 17.93s/it]
# 2.0595474243164062
# tensor(0.2500, device='cuda:0')
# epoch 000 | phase train:   0%|          | 6/1730 [01:28<6:56:48, 14.51s/it]
# 1.8177365064620972
# tensor(0.2500, device='cuda:0')
# epoch 000 | phase train:   0%|          | 7/1730 [01:38<6:19:25, 13.21s/it]
# 1.7243027687072754
# tensor(0.2500, device='cuda:0')
# epoch 000 | phase train:   0%|          | 8/1730 [01:45<5:19:36, 11.14s/it]
# ...

# %%
phase = 'test'
running_loss, running_corrects = 0.0, 0
model.eval()
for inputs, labels in tqdm(dataloaders[phase], desc= f"epoch {str(epoch).zfill(3)} | phase {phase.ljust(5)}"):
  inputs = inputs.to(device)
  labels = labels.to(device)

  optimizer.zero_grad()

  outputs = model(inputs)
  _, preds = torch.max(outputs, 1)


  running_corrects += torch.sum(preds == labels.data)
  print(torch.sum(preds == labels.data)/batch_size)
  # Clear memory and collect garbage
  del inputs, labels, outputs, preds
  gc.collect()

epoch_acc = running_corrects.double() / dataset_sizes[phase]
print(f'Acc: {epoch_acc:.4f}')
# Out:
# epoch 000 | phase test :   0%|          | 1/433 [00:12<1:29:59, 12.50s/it]
# tensor(0.7500, device='cuda:0')
# epoch 000 | phase test :   0%|          | 2/433 [00:16<53:50,  7.50s/it]
# tensor(1., device='cuda:0')
# epoch 000 | phase test :   1%|          | 3/433 [00:26<1:01:40,  8.61s/it]
# tensor(0.7500, device='cuda:0')
# epoch 000 | phase test :   1%|          | 4/433 [00:32<55:47,  7.80s/it]
# tensor(0.7500, device='cuda:0')
# epoch 000 | phase test :   1%|          | 5/433 [00:39<51:25,  7.21s/it]
# tensor(1., device='cuda:0')
# epoch 000 | phase test :   1%|▏         | 6/433 [00:42<41:28,  5.83s/it]
# tensor(0.7500, device='cuda:0')
# epoch 000 | phase test :   2%|▏         | 7/433 [00:57<1:03:17,  8.91s/it]
# tensor(1., device='cuda:0')
# epoch 000 | phase test :   2%|▏         | 8/433 [01:08<1:07:08,  9.48s/it]
# tensor(1., device='cuda:0')
# epoch 000 | phase test :   2%|▏         | 9/433 [01:35<1:45:57, 14.99s/it]
# tensor(1., device='cuda:0')
# ...
